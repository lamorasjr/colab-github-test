# %%
import requests
import pandas as pd

url = "https://randomuser.me/api/"

response = requests.get(url).json()

df = pd.json_normalize(response, "results")
df
# Out:
#   gender                       email           phone            cell nat  \
# 0   male  isaac.gonzalez@example.com  02-77-56-58-20  06-91-36-51-91  FR
#
#   name.title name.first name.last  location.street.number  \
# 0         Mr      Isaac  Gonzalez                    2286
#
#   location.street.name  ...  \
# 0      Rue des Jardins  ...
#
#                                         login.sha256  \
# 0  649a060bd173690af16b63aace89eae2685ec6bfe3d3d4...
#
#                    dob.date dob.age           registered.date registered.age  \
# 0  1995-04-09T08:53:29.074Z      29  2013-09-22T01:34:35.023Z             10
#
#   id.name          id.value                                   picture.large  \
# 0   INSEE  1950321488575 28  https://randomuser.me/api/portraits/men/23.jpg
#
#                                       picture.medium  \
# 0  https://randomuser.me/api/portraits/med/men/23...
#
#                                    picture.thumbnail
# ...
